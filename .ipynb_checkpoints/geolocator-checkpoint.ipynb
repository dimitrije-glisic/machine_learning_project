# %% [markdown]
# ## Maps address to geolocation data

# %% [markdown]
# ### Takes about 10 minutes to execute

# %%
import sys
print(sys.path)
sys.path.append('/home/upflo/.local/lib/python3.6/site-packages')

import pandas as pd

from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut
# Out:
# ['/usr/lib/python36.zip', '/usr/lib/python3.6', '/usr/lib/python3.6/lib-dynload', '', '/home/upflo/fakultet/psz/venv/lib/python3.6/site-packages', '/home/upflo/fakultet/psz/venv/lib/python3.6/site-packages/IPython/extensions', '/home/upflo/.ipython']

# %%
df = pd.read_csv('./data_odbrana', lineterminator='\n', header='infer')
df = df[(df.tip == 'stan') & (df.grad=='Beograd') & (df.usluga =='prodaja')]

# %% [markdown]
# scikit: 0.6660136704001539
# me: 0.6660244552713956

# %% [markdown]
# rstate-99: score=0.6397337485676919 za w=0.8
#
# rstate-30: score=0.3287777175616837 za w=0.8
#
# rstate-20: score=0.7241704816698431 za w=0.5
#
# rstate-10: score=0.7142950251759101 za w=0.9
#
# rstate-14: score=0.3323556617247425 za w=1
#
# rstate-24: score=0.6108660992396076 za w=0.6
#
# max for w=0.9: 0.6990914523516469

# %%
geolocator = Nominatim(user_agent="psz_projekat")
def geocode(adresa, recursion=0):
    try:
        return geolocator.geocode(adresa)
    except BaseException as e:
        if recursion > 10:      # max recursions
            raise e

        time.sleep(1) # wait a bit
        # try again
        return geocode(adresa, recursion=recursion + 1)

# %%
adresa_to_geoloc = dict()
uniq = df.adresa.unique()
for adresa in uniq:
    adresa_to_geoloc[adresa] = geocode('Beograd' + ' ' + adresa)
    
df['latitude'] = df['adresa'].map(lambda adresa:adresa_to_geoloc[adresa].latitude if adresa in uniq and adresa_to_geoloc[adresa] else None)
df['longitude'] = df['adresa'].map(lambda adresa: adresa_to_geoloc[adresa].longitude if adresa in uniq and adresa_to_geoloc[adresa] else None)

df = df[df.latitude.notna()]

knez_mihailova = geocode('Knez Mihailova')
knez_mihailova_lat_long = (knez_mihailova.latitude, knez_mihailova.longitude)

from geopy import distance

def calculate_distance(row):
    centar = (44.8178925, 20.4569641)
    stan = (row.latitude, row.longitude)
    row.udaljenost_od_centra = distance.distance(centar, stan).km
    return row

df['udaljenost_od_centra'] = 0.0
df = df.apply(calculate_distance, axis=1)

# %%
df.head()
# Out:
#         usluga   tip       cena     grad       sira_lokacija  \
# 3      prodaja  stan    2.000 €  Beograd    Palilula opština
# 5      prodaja  stan  275.000 €  Beograd    Zvezdara opština
# 6      prodaja  stan  270.000 €  Beograd    Palilula opština
# 8      prodaja  stan  610.000 €  Beograd              Vračar
# 10     prodaja  stan  193.000 €  Beograd  Stari Grad opština
# ...        ...   ...        ...      ...                 ...
# 15210  prodaja  stan  209.000 €  Beograd        Savski Venac
# 15211  prodaja  stan  120.000 €  Beograd       Zemun opština
# 15212  prodaja  stan   53.000 €  Beograd        Novi Beograd
# 15213  prodaja  stan   64.200 €  Beograd    Palilula opština
# 15214  prodaja  stan  245.000 €  Beograd        Novi Beograd
#
#              uza_lokacija                     adresa povrsina  plac broj_soba  \
# 3                 Krnjača  Partizanski blok ulica 1.     50m²   NaN    2 sobe
# 5                    Lion                   Batutova    162m²   NaN    6 soba
# 6                Palilula     Dr Dragoslava Popovića    105m²   NaN    4 sobe
# 8                  Neimar                Braničevska    153m²   NaN    4 sobe
# 10                 Dorćol                  Dobračina     72m²   NaN  2.5 sobe
# ...                   ...                        ...      ...   ...       ...
# 15210     Beograd na vodi            Beograd na vodi     56m²   NaN    2 sobe
# 15211               Zemun            Kej oslobođenja     64m²   NaN    2 sobe
# 15212              Ledine                Luja Daviča     36m²   NaN    1 soba
# 15213           Karaburma      Vojvode Micka Krstića     48m²   NaN    1 soba
# 15214  Blok 67 - Belville            Jurija Gagarina    100m²   NaN    3 sobe
#
#        ... orijentacija_nekretnine tip_objekta  tip_stana tip_kuce  \
# 3      ...                     NaN         NaN        NaN      NaN
# 5      ...                     NaN         NaN        NaN      NaN
# 6      ...                     NaN         NaN        NaN      NaN
# 8      ...                     NaN         NaN        NaN      NaN
# 10     ...                     NaN         NaN        NaN      NaN
# ...    ...                     ...         ...        ...      ...
# 15210  ...                     NaN         NaN        NaN      NaN
# 15211  ...                     NaN         NaN        NaN      NaN
# 15212  ...                     NaN         NaN        NaN      NaN
# 15213  ...                     NaN         NaN        NaN      NaN
# 15214  ...                     NaN         NaN        NaN      NaN
#
#       sifra_oglasa                                               opis  \
# 3             1080  U prilici smo da Vam ponudimo stanove građene ...
# 5             1958  AGENCIJSKA PROVIZIJA 2% OPIS NEKRETNINE : uknj...
# 6        102447624  Agencijski ID: 47624, III/V, klima, lift, tele...
# 8               65  Izuzetan stan u novogradnji vrhunskog kvalitet...
# 10             NaN  U centru grada na odličnoj lokaciji prodajemo ...
# ...            ...                                                ...
# 15210        57046  Stan se sastoji od dnevne sobe sa trpezarijom,...
# 15211        41587                          (agencijska provizija 2%)
# 15212        56790  Prelep, jednosoban stan, vrlo lako adaptibilan...
# 15213        55607  Stan na petom spratu (nadogradnja) u zgradi be...
# 15214        13196  Lux, kvalitetan stan, opremljen po dogovoru, d...
#
#                                                     link   latitude  \
# 3      https://www.4zida.rs/prodaja/stanovi/beograd/o...  44.842779
# 5      https://www.4zida.rs/prodaja/stanovi/beograd/o...  44.797302
# 6      https://www.4zida.rs/prodaja/stanovi/beograd/o...  44.811951
# 8      https://www.4zida.rs/prodaja/stanovi/beograd/o...  44.794506
# 10     https://www.4zida.rs/prodaja/stanovi/beograd/o...  44.819149
# ...                                                  ...        ...
# 15210  https://www.4zida.rs/prodaja/stanovi/beograd/o...  44.804993
# 15211  https://www.4zida.rs/prodaja/stanovi/beograd/o...  44.847170
# 15212  https://www.4zida.rs/prodaja/stanovi/beograd/o...  44.808065
# 15213  https://www.4zida.rs/prodaja/stanovi/beograd/o...  44.815186
# 15214  https://www.4zida.rs/prodaja/stanovi/beograd/o...  44.799077
#
#        longitude udaljenost_od_centra
# 3      20.483710             3.481600
# 5      20.499415             4.063796
# 6      20.474358             1.526104
# 8      20.469430             2.779669
# 10     20.462108             0.430149
# ...          ...                  ...
# 15210  20.448491             1.582482
# 15211  20.414237             4.690503
# 15212  20.346967             8.769367
# 15213  20.505490             3.850068
# 15214  20.376459             6.703100
#
# [3008 rows x 34 columns]

# %%
df.shape

# %%
df.to_csv('./adr_to_distance_new_backup.csv', encoding='utf-8', index=False)
